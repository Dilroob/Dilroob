# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=['apple','orange','banana','cherry']
y=[21,23,44,53]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,color='green')

# %%
plt.plot(x,y,marker='*',mec='yellow',mfc='red')

# %%
plt.plot(x,y,linewidth=5,linestyle='dotted')

# %%
plt.plot(x,y,linewidth=5,linestyle='-.')

# %%
plt.plot(x,y,linewidth=5,marker='*',ms=15)

# %%
plt.plot(x,y)
plt.xlabel('fruits')
plt.ylabel('quantity')
# Out:
# Text(0, 0.5, 'quantity')

# %%
plt.plot(x,y)
plt.xlabel('fruits')
plt.ylabel('quantity')
plt.title('fruits vs quantity')
# Out:
# Text(0.5, 1.0, 'fruits vs quantity')

# %%
plt.plot(x,y)
plt.xlabel('fruits')
plt.ylabel('quantity')
plt.title('fruits vs quantity')
plt.grid()

# %%
plt.plot(x,y)
plt.xlabel('fruits',loc='right')
plt.ylabel('quantity',loc='bottom')
plt.title('fruits vs quantity',loc='left')
plt.grid()

# %%
plt.figure(figsize=(10,8))
plt.plot(x,y)

# %%
a=['january','february','march','april','may','june']
b=[1222,1544,3750,7891,6656,4090]

# %%
plt.plot(a,b)
plt.show()

# %%
plt.plot(a,b,color='green')

# %%
plt.plot(a,b,marker='*',mec='yellow',mfc='red')

# %%
plt.plot(a,b,linewidth=5,linestyle='dotted')

# %%
plt.plot(a,b,linewidth=5,linestyle='-.')

# %%
plt.plot(a,b,linewidth=5,marker='*',ms=15)

# %%
plt.plot(a,b)
plt.xlabel('month')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.plot(a,b)
plt.xlabel('month')
plt.ylabel('sales')
plt.title('monthly sales')
# Out:
# Text(0.5, 1.0, 'monthly sales')

# %%
plt.plot(a,b)
plt.xlabel('month')
plt.ylabel('sales')
plt.title('monthly sales')
plt.grid()

# %%
plt.figure(figsize=(10,10))
plt.plot(a,b,color='green',marker='*',mec='yellow',mfc='red',linewidth=5,linestyle='-.')
plt.xlabel('month',loc='left')
plt.ylabel('sales',loc='bottom')
plt.title('monthly sales of 6 months',loc='right')
plt.grid()

# %%
# multiple plot

x=[5,7,8,7]
y=[3,7,8,9]
plt.plot(x)
plt.plot(y)

# %%
plt.figure(figsize=(10, 6))
x=['jan','feb','march','april','may','june']
y1=[101,105,106,108,109,113]
y2=[100,110,106,119,120,134]
plt.plot(x,y1,marker='o',label='WEST')
plt.plot(x,y2,marker='*',label='EAST')
plt.xlabel('MONTHS')
plt.ylabel('SALES')
plt.title('MONTHLY SALES: WEST VS EAST')
plt.grid()

# %%
x=['razin','nihal','rameez','naseef','dilroob']
y=[12,9,37,46,50]
plt.plot(x,y,marker='*',color='black',linestyle='dashed',linewidth=2)
plt.title('simple line plot',color='green',fontsize=15,fontstyle='italic')
plt.xlabel('names')
plt.ylabel('marks')
plt.grid(axis='x')
plt.show()

# %%
x=['razin','nihal','rameez','naseef','dilroob']
y=[12,9,37,46,50]
plt.plot(x,y,marker='*',color='black',linestyle='dashed',linewidth=2)
font={'family':'broadway','color':'red','size':15,'style':'italic'}
plt.title('simple line plot',color='green',fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font)
plt.grid(axis='x')
plt.show()

# %%
# subplot

x=['razin','nihal','rameez','naseef','dilroob']
y=[12,9,37,46,50]
plt.subplot(1,2,2)   # no of rows, no of columns,no of positions
plt.plot(x,y,marker='*',color='red')

x=['razin','nihal','rameez','naseef','dilroob']
y=[29,16,39,48,43]
plt.subplot(1,2,1)   # no of rows, no of columns,no of positions
plt.plot(x,y,marker='*',color='red')

# %%
x=['razin','nihal','rameez','naseef','dilroob']
y=[12,9,37,46,50]
plt.subplot(2,2,1)   
plt.plot(x,y,marker='*',color='red')

x=['razin','nihal','rameez','naseef','dilroob']
y=[29,16,39,48,43]
plt.subplot(2,2,2)   
plt.plot(x,y,marker='*',color='red')


x=['razin','nihal','rameez','naseef','dilroob']
y=[24,37,14,44,49]
plt.subplot(2,2,3)   
plt.plot(x,y,marker='*',color='red')

x=['razin','nihal','rameez','naseef','dilroob']
y=[30,20,10,40,50]
plt.subplot(2,2,4) 
plt.plot(x,y,marker='*',color='red')

# %%
x=['razin','nihal','rameez','naseef','dilroob']
y=[12,9,37,46,50]
plt.bar(x,y,color='red',alpha=0.6,width=0.5)
plt.xticks(rotation=45)
plt.yticks(rotation=30)
# Out:
# (array([ 0., 10., 20., 30., 40., 50., 60.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 10.0, '10'),
#   Text(0, 20.0, '20'),
#   Text(0, 30.0, '30'),
#   Text(0, 40.0, '40'),
#   Text(0, 50.0, '50'),
#   Text(0, 60.0, '60')])

# %%
x=['razin','nihal','rameez','naseef','dilroob']
y=[12,9,37,46,50]
plt.barh(x,y,color='red',alpha=0.6,height=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(10,10))
font={'family':'broadway','color':'red','size':15}
font1={'family':'serif','color':'blue','size':15}

x=['razin','nihal','rameez','naseef','dilroob','aslah']
y=[11,33,22,11,44,22]
plt.subplot(3,2,1)
plt.title('maths',color='green',size=20,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.plot(x,y,marker='*',color='yellow')
plt.grid()

x=['razin','nihal','rameez','naseef','dilroob','aslah']
y=[12,9,37,46,46,50]
plt.subplot(3,2,2)  
plt.title('english',color='green',size=20,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.plot(x,y,marker='*',color='maroon')
plt.grid()

x=['razin','nihal','rameez','naseef','dilroob','aslah']
y=[29,16,39,48,43,48]
plt.subplot(3,2,3)
plt.title('hindi',color='green',size=20,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.bar(x,y,color='black')


x=['razin','nihal','rameez','naseef','dilroob','aslah']
y=[24,37,14,44,49,48]
plt.subplot(3,2,4)  
plt.title('chemistry',color='green',size=20,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.bar(x,y,color='orange')

x=['razin','nihal','rameez','naseef','dilroob','aslah']
y=[50,35,20,25,10,15]
plt.subplot(3,2,5)
plt.title('malayalam',color='green',size=20,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.barh(x,y,color='pink')

x=['razin','nihal','rameez','naseef','dilroob','aslah']
y=[30,20,10,40,50,50]
plt.subplot(3,2,6)
plt.title('physics',color='green',size=20,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.barh(x,y,color='purple')

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Pie Chart

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']    # used to give label
plt.pie(a,startangle=90,labels=l)    # startangle is used to define the starting of the chart
# Out:
# ([<matplotlib.patches.Wedge at 0x22105d32510>,
# ...
#  [Text(-0.6766425944927579, 0.8672685854555723, 'hr'),
#   Text(-1.0487583096055664, -0.33182225367397383, 'it'),
#   Text(0.6025796765196304, -0.9202704675504358, 'sales'),
#   Text(0.652445339653442, 0.8856156495706842, 'randd')])

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
exp=[0,0.2,0,0]
plt.pie(a,explode=exp,labels=l)    # used to get specific slice separeted
# Out:
# ([<matplotlib.patches.Wedge at 0x22106eece10>,
# ...
#  [Text(0.8672686150325598, 0.6766425565832419, 'hr'),
#   Text(-0.392153370593108, 1.2394417025146705, 'it'),
#   Text(-0.9202705657231139, -0.6025795265885324, 'sales'),
#   Text(0.8856155432738343, -0.6524454839385369, 'randd')])

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
exp=[0,0.2,0,0.3]
plt.pie(a,explode=exp,labels=l)
# Out:
# ([<matplotlib.patches.Wedge at 0x22106f356d0>,
# ...
#  [Text(0.8672686150325598, 0.6766425565832419, 'hr'),
#   Text(-0.392153370593108, 1.2394417025146705, 'it'),
#   Text(-0.9202705657231139, -0.6025795265885324, 'sales'),
#   Text(1.1271470550757892, -0.8303851613763196, 'randd')])

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
plt.pie(a,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22106f85590>,
# ...
#  [Text(0.8672686150325598, 0.6766425565832419, ''),
#   Text(-0.33182208280955294, 1.0487583636662596, ''),
#   Text(-0.9202705657231139, -0.6025795265885324, ''),
#   Text(0.8856155432738343, -0.6524454839385369, '')],
#  [Text(0.47305560819957804, 0.36907775813631377, '21.1%'),
#   Text(-0.18099386335066522, 0.5720500165452325, '17.6%'),
#   Text(-0.5019657631216985, -0.32867974177556314, '41.1%'),
#   Text(0.48306302360390957, -0.3558793548755655, '20.2%')])

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
plt.pie(a,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22105da9810>,
# ...
#  [Text(0.8672686150325598, 0.6766425565832419, ''),
#   Text(-0.33182208280955294, 1.0487583636662596, ''),
#   Text(-0.9202705657231139, -0.6025795265885324, ''),
#   Text(0.8856155432738343, -0.6524454839385369, '')],
#  [Text(0.47305560819957804, 0.36907775813631377, '21%'),
#   Text(-0.18099386335066522, 0.5720500165452325, '18%'),
#   Text(-0.5019657631216985, -0.32867974177556314, '41%'),
#   Text(0.48306302360390957, -0.3558793548755655, '20%')])

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
plt.pie(a,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22105df5a90>,
# ...
#  [Text(0.8672686150325598, 0.6766425565832419, ''),
#   Text(-0.33182208280955294, 1.0487583636662596, ''),
#   Text(-0.9202705657231139, -0.6025795265885324, ''),
#   Text(0.8856155432738343, -0.6524454839385369, '')],
#  [Text(0.47305560819957804, 0.36907775813631377, '21.09%'),
#   Text(-0.18099386335066522, 0.5720500165452325, '17.57%'),
#   Text(-0.5019657631216985, -0.32867974177556314, '41.12%'),
#   Text(0.48306302360390957, -0.3558793548755655, '20.21%')])

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
c=['blue','gold','silver','purple']
plt.pie(a,autopct='%1.0f%%',labels=l,colors=c)
# Out:
# ([<matplotlib.patches.Wedge at 0x22105e41d10>,
# ...
#  [Text(0.8672686150325598, 0.6766425565832419, 'hr'),
#   Text(-0.33182208280955294, 1.0487583636662596, 'it'),
#   Text(-0.9202705657231139, -0.6025795265885324, 'sales'),
#   Text(0.8856155432738343, -0.6524454839385369, 'randd')],
#  [Text(0.47305560819957804, 0.36907775813631377, '21%'),
#   Text(-0.18099386335066522, 0.5720500165452325, '18%'),
#   Text(-0.5019657631216985, -0.32867974177556314, '41%'),
#   Text(0.48306302360390957, -0.3558793548755655, '20%')])

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
c=['blue','gold','silver','purple']
plt.pie(a,autopct='%1.0f%%',labels=l,colors=c)
plt.legend(l)

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
c=['blue','gold','silver','purple']
plt.pie(a,autopct='%1.0f%%',labels=l,colors=c)
plt.legend(l,loc='upper right')

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
c=['blue','gold','silver','purple']
plt.pie(a,autopct='%1.0f%%',labels=l,colors=c)
plt.legend(l,loc='upper right',title='chart',bbox_to_anchor=[1.3,1])  # bbox is used to remove the overlapping of graph
plt.title('pie chart')
# Out:
# Text(0.5, 1.0, 'pie chart')

# %%
a=[120,100,234,115]
l=['hr','it','sales','randd']
plt.pie(a,autopct='%1.0f%%',wedgeprops={'edgecolor':'black'},textprops={'fontsize':15},shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x221070e4cd0>,
# ...
#  [Text(0.8672686150325598, 0.6766425565832419, ''),
#   Text(-0.33182208280955294, 1.0487583636662596, ''),
#   Text(-0.9202705657231139, -0.6025795265885324, ''),
#   Text(0.8856155432738343, -0.6524454839385369, '')],
#  [Text(0.47305560819957804, 0.36907775813631377, '21%'),
#   Text(-0.18099386335066522, 0.5720500165452325, '18%'),
#   Text(-0.5019657631216985, -0.32867974177556314, '41%'),
#   Text(0.48306302360390957, -0.3558793548755655, '20%')])

# %%
plt.figure(figsize=(20,15))
font={'family':'serif','color':'red','size':20}
font1={'family':'monospace','color':'blue','size':20}
c=['blue','gold','red','purple']

a=[120,100,234,115]
l=['razin','nihal','naseef','dilroob']
plt.subplot(2,2,1)
exp=[0,0.1,0,0]
plt.pie(a,autopct='%1.0f%%',startangle=90,labels=l,explode=exp,colors=c,wedgeprops={'edgecolor':'black'},textprops={'fontsize':15},shadow=True)
plt.legend(l,loc='upper left',bbox_to_anchor=[1,1],title='chart')
plt.title('Pie Chart',color='green',size=30,fontdict=font)

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(2,2,2)  
plt.title('Line Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.plot(x,y,marker='*',color='blue',ms=18,mec='yellow',mfc='red',linewidth=5,linestyle='-.',alpha=0.8)
plt.grid(color='gold',linestyle='dotted')

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(2,2,3)  
plt.title('Bar Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.bar(x,y,color=c,alpha=0.8,width=0.5)

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(2,2,4)
plt.title('Hbar Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.barh(x,y,color=c,alpha=0.8,height=0.5)

plt.tight_layout()

# %%
# scatter plot              3 dtted representation to find the relation btw 2 numerical variable
study=[1,3,5,3,4,6]
marks=[21,12,35,67,59,78]
plt.scatter(study,marks,s=50)       # s=size

# %%
study=[1,3,5,3,4,6]
marks=[21,12,35,67,59,78]
size=[10,20,30,40,50,60]
color=['red','black','blue','pink','magenta','orange']
plt.scatter(study,marks,s=size,c=color)       # s=size

# %%
study=[1,3,5,3,4,6]
marks=[21,12,35,67,59,78]
size=[10,20,30,40,50,60]
color=['red','black','blue','pink','magenta','orange']
plt.scatter(study,marks,s=size,c=color,edgecolors='green',alpha=0.5) 
plt.grid(alpha=0.5)

# %% [markdown]
# # Histogram

# %%
a=[20,21,23,24,25,21,23,24,25,20,25,20,21,23,22,22]
plt.hist(a)
# Out:
# (array([3., 0., 3., 0., 2., 0., 3., 0., 2., 3.]),
#  array([20. , 20.5, 21. , 21.5, 22. , 22.5, 23. , 23.5, 24. , 24.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
a=[20,21,23,24,25,21,23,24,25,20,25,20,21,23,22,22]
plt.hist(a,bins=4)
# Out:
# (array([6., 2., 3., 5.]),
#  array([20.  , 21.25, 22.5 , 23.75, 25.  ]),
#  <BarContainer object of 4 artists>)

# %%
a=[20,21,23,24,25,21,23,24,25,20,25,20,21,23,22,22]
plt.hist(a,bins=4,color='magenta',edgecolor='black')
# Out:
# (array([6., 2., 3., 5.]),
#  array([20.  , 21.25, 22.5 , 23.75, 25.  ]),
#  <BarContainer object of 4 artists>)

# %%
# stock plot

x=['jan','feb','march','april','may']
sales=[12,23,45,67,87]
it=[34,23,21,32,22]
hr=[99,77,65,43,21]
plt.stackplot(x,sales,it,hr,edgecolor='black',labels=['sales','it','hr'],colors=['blue','red','green'])

# %%
# donut chart

a=[120,100,234,115]
l=['hr','it','sales','randd']
c=['blue','gold','silver','purple']
plt.pie(a,autopct='%1.0f%%',labels=l,colors=c,wedgeprops={'edgecolor':'black','width':0.4})
plt.legend(l,loc='upper right',title='chart',bbox_to_anchor=[1.3,1])  # bbox is used to remove the overlapping of graph
plt.title('pie chart')
# Out:
# Text(0.5, 1.0, 'pie chart')

# %%
plt.figure(figsize=(20,20))
font={'family':'serif','color':'red','size':20}
font1={'family':'monospace','color':'blue','size':20}
c=['orange','gold','red','purple']

a=[120,100,234,115]
l=['razin','nihal','naseef','dilroob']
plt.subplot(4,2,1)
exp=[0,0.3,0,0]
plt.pie(a,autopct='%1.0f%%',startangle=90,labels=l,explode=exp,colors=c,wedgeprops={'edgecolor':'black'},textprops={'fontsize':15},shadow=True)
plt.legend(l,loc='upper left',bbox_to_anchor=[1,1],title='chart')
plt.title('Pie Chart',color='green',size=30,fontdict=font)

a=[120,100,234,115]
l=['razin','nihal','naseef','dilroob']
plt.subplot(4,2,2)
plt.pie(a,autopct='%1.0f%%',startangle=90,labels=l,colors=c,wedgeprops={'edgecolor':'black','width':0.4},textprops={'fontsize':15},shadow=True)
plt.legend(l,loc='upper left',bbox_to_anchor=[1,1],title='chart')
plt.title('Donut Pie Chart',color='green',size=30,fontdict=font)

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(4,2,3)  
plt.title('Line Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.plot(x,y,marker='*',color='blue',ms=18,mec='yellow',mfc='red',linewidth=5,linestyle='-.',alpha=0.8)
plt.grid(color='gold',linestyle='dotted')

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(4,2,4)  
plt.title('Scatter Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.scatter(x,y,marker='*',s=200,color=c,alpha=0.8)
plt.grid(color='gold',linestyle='dotted')

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(4,2,5)  
plt.title('Bar Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.bar(x,y,color=c,alpha=0.8,width=0.5)

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(4,2,6)
plt.title('Hbar Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.barh(x,y,color=c,alpha=0.8,height=0.5)

y=[20,21,23,24,25,21,23,24,25,20,25,20,21,23,22,22]
plt.subplot(4,2,7)  
plt.title('Bar Graph',color='green',size=30,fontdict=font)
plt.hist(y,bins=4,color='black',edgecolor='red')

x=['jan','feb','march','april','may']
sales=[12,23,45,67,87]
it=[34,23,21,32,22]
hr=[99,77,65,43,21]
plt.subplot(4,2,8) 
plt.title('Histogram',color='green',size=30,fontdict=font)
plt.xlabel('months',fontdict=font)
plt.ylabel('sales',fontdict=font1)
plt.stackplot(x,sales,it,hr,edgecolor='black',labels=['sales','it','hr'],colors=c)

plt.tight_layout()

# %%
plt.figure(figsize=(20,20))
font={'family':'serif','color':'red','size':20}
font1={'family':'monospace','color':'blue','size':20}
c=['orange','gold','red','purple']

a=[120,100,234,115]
l=['razin','nihal','naseef','dilroob']
plt.subplot(4,2,1)
exp=[0,0.3,0,0]
plt.pie(a,autopct='%1.0f%%',startangle=90,labels=l,explode=exp,colors=c,wedgeprops={'edgecolor':'black'},textprops={'fontsize':15},shadow=True)
plt.legend(l,loc='upper left',bbox_to_anchor=[1,1],title='chart')
plt.title('Pie Chart',color='green',size=30,fontdict=font)

a=[120,100,234,115]
l=['razin','nihal','naseef','dilroob']
plt.subplot(4,2,2)
plt.pie(a,autopct='%1.0f%%',startangle=90,labels=l,colors=c,wedgeprops={'edgecolor':'black','width':0.4},textprops={'fontsize':15},shadow=True)
plt.legend(l,loc='upper left',bbox_to_anchor=[1,1],title='chart')
plt.title('Donut Pie Chart',color='green',size=30,fontdict=font)

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(4,2,3)  
plt.title('Line Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.plot(x,y,marker='*',color='blue',ms=18,mec='yellow',mfc='red',linewidth=5,linestyle='-.',alpha=0.8)
plt.grid(color='gold',linestyle='dotted')

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(4,2,4)  
plt.title('Scatter Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.scatter(x,y,marker='*',s=200,color=c,alpha=0.8)
plt.grid(color='gold',linestyle='dotted')

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(4,2,5)  
plt.title('Bar Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.bar(x,y,color=c,alpha=0.8,width=0.5)

x=['razin','nihal','naseef','dilroob']
y=[120,100,234,115]
plt.subplot(4,2,6)
plt.title('Hbar Graph',color='green',size=30,fontdict=font)
plt.xlabel('names',fontdict=font)
plt.ylabel('marks',fontdict=font1)
plt.barh(x,y,color=c,alpha=0.8,height=0.5)

y=[20,21,23,24,25,21,23,24,25,20,25,20,21,23,22,22]
plt.subplot(4,2,7)  
plt.title('Bar Graph',color='green',size=30,fontdict=font)
plt.hist(y,bins=4,color='black',edgecolor='red')

x=['jan','feb','march','april','may']
sales=[12,23,45,67,87]
it=[34,23,21,32,22]
hr=[99,77,65,43,21]
plt.subplot(4,2,8) 
plt.title('Histogram',color='green',size=30,fontdict=font)
plt.xlabel('months',fontdict=font)
plt.ylabel('sales',fontdict=font1)
plt.stackplot(x,sales,it,hr,edgecolor='black',labels=['sales','it','hr'],colors=c)

plt.tight_layout()
