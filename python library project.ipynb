# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\dilro\Downloads\archive\events.csv")
df
# Out:
#           id_odsp     id_event  sort_order  time  \
# 0       UFot0hit/    UFot0hit1           1     2
# 1       UFot0hit/    UFot0hit2           2     4
# 2       UFot0hit/    UFot0hit3           3     4
# 3       UFot0hit/    UFot0hit4           4     7
# 4       UFot0hit/    UFot0hit5           5     7
# ...           ...          ...         ...   ...
# 941004  z5L2OT5E/  z5L2OT5E123         123    92
# 941005  z5L2OT5E/  z5L2OT5E124         124    93
# 941006  z5L2OT5E/  z5L2OT5E125         125    93
# 941007  z5L2OT5E/  z5L2OT5E126         126    94
# 941008  z5L2OT5E/  z5L2OT5E127         127    94
#
#                                                      text  event_type  \
# 0       Attempt missed. Mladen Petric (Hamburg) left f...           1
# 1       Corner,  Borussia Dortmund. Conceded by Dennis...           2
# 2       Corner,  Borussia Dortmund. Conceded by Heiko ...           2
# 3                Foul by Sven Bender (Borussia Dortmund).           3
# ...

# %%
df.size
# Out:
# 20702198

# %%
df.shape
# Out:
# (941009, 22)

# %%
df.columns
# Out:
# Index(['id_odsp', 'id_event', 'sort_order', 'time', 'text', 'event_type',
#        'event_type2', 'side', 'event_team', 'opponent', 'player', 'player2',
#        'player_in', 'player_out', 'shot_place', 'shot_outcome', 'is_goal',
#        'location', 'bodypart', 'assist_method', 'situation', 'fast_break'],
#       dtype='object')

# %%
df.head()
# Out:
#      id_odsp   id_event  sort_order  time  \
# 0  UFot0hit/  UFot0hit1           1     2
# 1  UFot0hit/  UFot0hit2           2     4
# 2  UFot0hit/  UFot0hit3           3     4
# 3  UFot0hit/  UFot0hit4           4     7
# 4  UFot0hit/  UFot0hit5           5     7
#
#                                                 text  event_type  event_type2  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1         12.0
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2          NaN
# 2  Corner,  Borussia Dortmund. Conceded by Heiko ...           2          NaN
# 3           Foul by Sven Bender (Borussia Dortmund).           3          NaN
# 4  Gokhan Tore (Hamburg) wins a free kick in the ...           8          NaN
#
#    side         event_team           opponent  ... player_in player_out  \
# 0     2         Hamburg SV  Borussia Dortmund  ...       NaN        NaN
# 1     1  Borussia Dortmund         Hamburg SV  ...       NaN        NaN
# ...

# %%
df.tail()
# Out:
#           id_odsp     id_event  sort_order  time  \
# 941004  z5L2OT5E/  z5L2OT5E123         123    92
# 941005  z5L2OT5E/  z5L2OT5E124         124    93
# 941006  z5L2OT5E/  z5L2OT5E125         125    93
# 941007  z5L2OT5E/  z5L2OT5E126         126    94
# 941008  z5L2OT5E/  z5L2OT5E127         127    94
#
#                                                      text  event_type  \
# 941004  Lucas Torreira (Sampdoria) wins a free kick in...           8
# 941005   Corner,  Sampdoria. Conceded by Andrea Masiello.           2
# 941006  Attempt missed. Fabio Quagliarella (Sampdoria)...           1
# 941007  Alberto Grassi (Atalanta) wins a free kick on ...           8
# 941008                 Foul by Pedro Pereira (Sampdoria).           3
#
#         event_type2  side event_team   opponent  ... player_in player_out  \
# 941004          NaN     2  Sampdoria   Atalanta  ...       NaN        NaN
# 941005          NaN     2  Sampdoria   Atalanta  ...       NaN        NaN
# ...

# %%
df.head(2)
# Out:
#      id_odsp   id_event  sort_order  time  \
# 0  UFot0hit/  UFot0hit1           1     2
# 1  UFot0hit/  UFot0hit2           2     4
#
#                                                 text  event_type  event_type2  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1         12.0
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2          NaN
#
#    side         event_team           opponent  ... player_in player_out  \
# 0     2         Hamburg SV  Borussia Dortmund  ...       NaN        NaN
# 1     1  Borussia Dortmund         Hamburg SV  ...       NaN        NaN
#
#   shot_place shot_outcome  is_goal  location  bodypart  assist_method  \
# 0        6.0          2.0        0       9.0       2.0              1
# 1        NaN          NaN        0       NaN       NaN              0
#
#    situation  fast_break
# 0        1.0           0
# 1        NaN           0
#
# [2 rows x 22 columns]

# %%
df.tail(2)
# Out:
#           id_odsp     id_event  sort_order  time  \
# 941007  z5L2OT5E/  z5L2OT5E126         126    94
# 941008  z5L2OT5E/  z5L2OT5E127         127    94
#
#                                                      text  event_type  \
# 941007  Alberto Grassi (Atalanta) wins a free kick on ...           8
# 941008                 Foul by Pedro Pereira (Sampdoria).           3
#
#         event_type2  side event_team   opponent  ... player_in player_out  \
# 941007          NaN     1   Atalanta  Sampdoria  ...       NaN        NaN
# 941008          NaN     2  Sampdoria   Atalanta  ...       NaN        NaN
#
#        shot_place shot_outcome  is_goal  location  bodypart  assist_method  \
# 941007        NaN          NaN        0       4.0       NaN              0
# 941008        NaN          NaN        0       NaN       NaN              0
#
#         situation  fast_break
# 941007        NaN           0
# 941008        NaN           0
#
# [2 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941009 entries, 0 to 941008
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id_odsp        941009 non-null  object
#  1   id_event       941009 non-null  object
#  2   sort_order     941009 non-null  int64
#  3   time           941009 non-null  int64
#  4   text           941009 non-null  object
#  5   event_type     941009 non-null  int64
#  6   event_type2    214293 non-null  float64
#  7   side           941009 non-null  int64
#  8   event_team     941009 non-null  object
#  9   opponent       941009 non-null  object
#  10  player         880009 non-null  object
#  11  player2        291310 non-null  object
#  12  player_in      51715 non-null   object
#  13  player_out     51738 non-null   object
#  14  shot_place     227459 non-null  float64
#  15  shot_outcome   228498 non-null  float64
#  16  is_goal        941009 non-null  int64
# ...

# %%
df.describe()
# Out:
#           sort_order           time     event_type    event_type2  \
# count  941009.000000  941009.000000  941009.000000  214293.000000
# mean       53.858826      49.663663       4.326575      12.233764
# std        32.014268      26.488977       2.995313       0.468850
# min         1.000000       0.000000       1.000000      12.000000
# 25%        27.000000      27.000000       2.000000      12.000000
# 50%        53.000000      51.000000       3.000000      12.000000
# 75%        79.000000      73.000000       8.000000      12.000000
# max       180.000000     100.000000      11.000000      15.000000
#
#                 side     shot_place   shot_outcome        is_goal  \
# count  941009.000000  227459.000000  228498.000000  941009.000000
# mean        1.481170       5.733693       1.926555       0.025978
# std         0.499646       3.326100       0.797055       0.159071
# min         1.000000       1.000000       1.000000       0.000000
# ...

# %%
df['opponent']
# Out:
# 0         Borussia Dortmund
# 1                Hamburg SV
# 2                Hamburg SV
# 3                Hamburg SV
# 4         Borussia Dortmund
#                 ...
# 941004             Atalanta
# 941005             Atalanta
# 941006             Atalanta
# 941007            Sampdoria
# 941008             Atalanta
# Name: opponent, Length: 941009, dtype: object

# %%
df['event_team']
# Out:
# 0                Hamburg SV
# 1         Borussia Dortmund
# 2         Borussia Dortmund
# 3         Borussia Dortmund
# 4                Hamburg SV
#                 ...
# 941004            Sampdoria
# 941005            Sampdoria
# 941006            Sampdoria
# 941007             Atalanta
# 941008            Sampdoria
# Name: event_team, Length: 941009, dtype: object

# %%
df['text'].unique()
# Out:
# array(['Attempt missed. Mladen Petric (Hamburg) left footed shot from the left side of the box is high and wide to the left. Assisted by Gokhan Tore.',
#        'Corner,  Borussia Dortmund. Conceded by Dennis Diekmeier.',
#        'Corner,  Borussia Dortmund. Conceded by Heiko Westermann.', ...,
#        'Attempt saved. Alejandro Gomez (Atalanta) right footed shot from the left side of the box is saved in the centre of the goal. Assisted by Andrea Petagna.',
#        'Substitution, Atalanta. Rafael Toloi replaces Alejandro Gomez.',
#        'Attempt missed. Fabio Quagliarella (Sampdoria) right footed shot from the left side of the box misses to the left. Assisted by Lucas Torreira following a corner.'],
#       shape=(366076,), dtype=object)

# %%
df['location'].dtype
# Out:
# dtype('float64')

# %%
df['time'].min()
# Out:
# 0

# %%
df['time'].max()
# Out:
# 100

# %%
df['time'].mean()
# Out:
# np.float64(49.663663153062295)

# %%
df.isnull()
# Out:
#         id_odsp  id_event  sort_order   time   text  event_type  event_type2  \
# 0         False     False       False  False  False       False        False
# 1         False     False       False  False  False       False         True
# 2         False     False       False  False  False       False         True
# 3         False     False       False  False  False       False         True
# 4         False     False       False  False  False       False         True
# ...         ...       ...         ...    ...    ...         ...          ...
# 941004    False     False       False  False  False       False         True
# 941005    False     False       False  False  False       False         True
# 941006    False     False       False  False  False       False        False
# 941007    False     False       False  False  False       False         True
# 941008    False     False       False  False  False       False         True
#
# ...

# %%
df.isnull().sum()
# Out:
# id_odsp               0
# id_event              0
# sort_order            0
# time                  0
# text                  0
# event_type            0
# event_type2      726716
# side                  0
# event_team            0
# opponent              0
# player            61000
# player2          649699
# player_in        889294
# player_out       889271
# shot_place       713550
# shot_outcome     712511
# is_goal               0
# location         473942
# bodypart         711824
# assist_method         0
# situation        711872
# fast_break            0
# dtype: int64

# %%
df.isna()
# Out:
#         id_odsp  id_event  sort_order   time   text  event_type  event_type2  \
# 0         False     False       False  False  False       False        False
# 1         False     False       False  False  False       False         True
# 2         False     False       False  False  False       False         True
# 3         False     False       False  False  False       False         True
# 4         False     False       False  False  False       False         True
# ...         ...       ...         ...    ...    ...         ...          ...
# 941004    False     False       False  False  False       False         True
# 941005    False     False       False  False  False       False         True
# 941006    False     False       False  False  False       False        False
# 941007    False     False       False  False  False       False         True
# 941008    False     False       False  False  False       False         True
#
# ...

# %%
df.isna().sum()
# Out:
# id_odsp               0
# id_event              0
# sort_order            0
# time                  0
# text                  0
# event_type            0
# event_type2      726716
# side                  0
# event_team            0
# opponent              0
# player            61000
# player2          649699
# player_in        889294
# player_out       889271
# shot_place       713550
# shot_outcome     712511
# is_goal               0
# location         473942
# bodypart         711824
# assist_method         0
# situation        711872
# fast_break            0
# dtype: int64

# %%
df['is_goal'].sum()
# Out:
# np.int64(24446)

# %%
df['event_team'].value_counts()
# Out:
# event_team
# Juventus         12054
# Fiorentina       11802
# Real Madrid      11644
# AC Milan         11633
# AS Roma          11482
#                  ...
# Crotone           1005
# Leganes            991
# RB Leipzig         942
# Middlesbrough      911
# Alaves             888
# Name: count, Length: 142, dtype: int64

# %%
df['matchs']=df['event_team'] + df['opponent']
df['matchs']
# Out:
# 0         Hamburg SVBorussia Dortmund
# 1         Borussia DortmundHamburg SV
# 2         Borussia DortmundHamburg SV
# 3         Borussia DortmundHamburg SV
# 4         Hamburg SVBorussia Dortmund
#                      ...
# 941004              SampdoriaAtalanta
# 941005              SampdoriaAtalanta
# 941006              SampdoriaAtalanta
# 941007              AtalantaSampdoria
# 941008              SampdoriaAtalanta
# Name: matchs, Length: 941009, dtype: object

# %%
df
# Out:
#           id_odsp     id_event  sort_order  time  \
# 0       UFot0hit/    UFot0hit1           1     2
# 1       UFot0hit/    UFot0hit2           2     4
# 2       UFot0hit/    UFot0hit3           3     4
# 3       UFot0hit/    UFot0hit4           4     7
# 4       UFot0hit/    UFot0hit5           5     7
# ...           ...          ...         ...   ...
# 941004  z5L2OT5E/  z5L2OT5E123         123    92
# 941005  z5L2OT5E/  z5L2OT5E124         124    93
# 941006  z5L2OT5E/  z5L2OT5E125         125    93
# 941007  z5L2OT5E/  z5L2OT5E126         126    94
# 941008  z5L2OT5E/  z5L2OT5E127         127    94
#
#                                                      text  event_type  \
# 0       Attempt missed. Mladen Petric (Hamburg) left f...           1
# 1       Corner,  Borussia Dortmund. Conceded by Dennis...           2
# 2       Corner,  Borussia Dortmund. Conceded by Heiko ...           2
# 3                Foul by Sven Bender (Borussia Dortmund).           3
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [id_odsp, id_event, sort_order, time, text, event_type, event_type2, side, event_team, opponent, player, player2, player_in, player_out, shot_place, shot_outcome, is_goal, location, bodypart, assist_method, situation, fast_break, matchs, substitutions]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.fillna('nil')
# Out:
#           id_odsp     id_event  sort_order  time  \
# 0       UFot0hit/    UFot0hit1           1     2
# 1       UFot0hit/    UFot0hit2           2     4
# 2       UFot0hit/    UFot0hit3           3     4
# 3       UFot0hit/    UFot0hit4           4     7
# 4       UFot0hit/    UFot0hit5           5     7
# ...           ...          ...         ...   ...
# 941004  z5L2OT5E/  z5L2OT5E123         123    92
# 941005  z5L2OT5E/  z5L2OT5E124         124    93
# 941006  z5L2OT5E/  z5L2OT5E125         125    93
# 941007  z5L2OT5E/  z5L2OT5E126         126    94
# 941008  z5L2OT5E/  z5L2OT5E127         127    94
#
#                                                      text  event_type  \
# 0       Attempt missed. Mladen Petric (Hamburg) left f...           1
# 1       Corner,  Borussia Dortmund. Conceded by Dennis...           2
# 2       Corner,  Borussia Dortmund. Conceded by Heiko ...           2
# 3                Foul by Sven Bender (Borussia Dortmund).           3
# ...

# %%
df.drop_duplicates()
# Out:
#           id_odsp     id_event  sort_order  time  \
# 0       UFot0hit/    UFot0hit1           1     2
# 1       UFot0hit/    UFot0hit2           2     4
# 2       UFot0hit/    UFot0hit3           3     4
# 3       UFot0hit/    UFot0hit4           4     7
# 4       UFot0hit/    UFot0hit5           5     7
# ...           ...          ...         ...   ...
# 941004  z5L2OT5E/  z5L2OT5E123         123    92
# 941005  z5L2OT5E/  z5L2OT5E124         124    93
# 941006  z5L2OT5E/  z5L2OT5E125         125    93
# 941007  z5L2OT5E/  z5L2OT5E126         126    94
# 941008  z5L2OT5E/  z5L2OT5E127         127    94
#
#                                                      text  event_type  \
# 0       Attempt missed. Mladen Petric (Hamburg) left f...           1
# 1       Corner,  Borussia Dortmund. Conceded by Dennis...           2
# 2       Corner,  Borussia Dortmund. Conceded by Heiko ...           2
# 3                Foul by Sven Bender (Borussia Dortmund).           3
# ...

# %%
df['situation'].fillna(df['situation'].mean(),inplace=True)
df
# Out:
# C:\Users\dilro\AppData\Local\Temp\ipykernel_20064\1255641323.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['situation'].fillna(df['situation'].mean(),inplace=True)
#           id_odsp     id_event  sort_order  time  \
# 0       UFot0hit/    UFot0hit1           1     2
# 1       UFot0hit/    UFot0hit2           2     4
# 2       UFot0hit/    UFot0hit3           3     4
# 3       UFot0hit/    UFot0hit4           4     7
# 4       UFot0hit/    UFot0hit5           5     7
# ...

# %%
df['shot_outcome'].fillna(df['shot_outcome'].mode()[0],inplace=True)
df
# Out:
# C:\Users\dilro\AppData\Local\Temp\ipykernel_20064\1609590500.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['shot_outcome'].fillna(df['shot_outcome'].mode()[0],inplace=True)
#           id_odsp     id_event  sort_order  time  \
# 0       UFot0hit/    UFot0hit1           1     2
# 1       UFot0hit/    UFot0hit2           2     4
# 2       UFot0hit/    UFot0hit3           3     4
# 3       UFot0hit/    UFot0hit4           4     7
# 4       UFot0hit/    UFot0hit5           5     7
# ...

# %%
df.loc[0,'opponent']
# Out:
# 'Borussia Dortmund'

# %%
df.loc[4,'text']
# Out:
# 'Gokhan Tore (Hamburg) wins a free kick in the defensive half.'

# %%
df.loc[3:4,['opponent','text']]
# Out:
#             opponent                                               text
# 3         Hamburg SV           Foul by Sven Bender (Borussia Dortmund).
# 4  Borussia Dortmund  Gokhan Tore (Hamburg) wins a free kick in the ...

# %%
df.iloc[3,2]
# Out:
# np.int64(4)

# %%
df[df['time']>30]
# Out:
#           id_odsp     id_event  sort_order  time  \
# 27      UFot0hit/   UFot0hit28          28    31
# 28      UFot0hit/   UFot0hit29          29    31
# 29      UFot0hit/   UFot0hit30          30    32
# 30      UFot0hit/   UFot0hit31          31    32
# 31      UFot0hit/   UFot0hit32          32    32
# ...           ...          ...         ...   ...
# 941004  z5L2OT5E/  z5L2OT5E123         123    92
# 941005  z5L2OT5E/  z5L2OT5E124         124    93
# 941006  z5L2OT5E/  z5L2OT5E125         125    93
# 941007  z5L2OT5E/  z5L2OT5E126         126    94
# 941008  z5L2OT5E/  z5L2OT5E127         127    94
#
#                                                      text  event_type  \
# 27         Foul by Kevin Grosskreutz (Borussia Dortmund).           3
# 28      Gokhan Tore (Hamburg) wins a free kick on the ...           8
# 29      Roman Weidenfeller (Borussia Dortmund) wins a ...           8
# 30          Corner,  Hamburg. Conceded by Ilkay Gundogan.           2
# ...

# %%
df[(df['time']<10) & (df['sort_order']<10)]
# Out:
#           id_odsp   id_event  sort_order  time  \
# 0       UFot0hit/  UFot0hit1           1     2
# 1       UFot0hit/  UFot0hit2           2     4
# 2       UFot0hit/  UFot0hit3           3     4
# 3       UFot0hit/  UFot0hit4           4     7
# 4       UFot0hit/  UFot0hit5           5     7
# ...           ...        ...         ...   ...
# 940890  z5L2OT5E/  z5L2OT5E3           3     2
# 940891  z5L2OT5E/  z5L2OT5E4           4     2
# 940892  z5L2OT5E/  z5L2OT5E5           5     2
# 940893  z5L2OT5E/  z5L2OT5E6           6     5
# 940894  z5L2OT5E/  z5L2OT5E7           7     5
#
#                                                      text  event_type  \
# 0       Attempt missed. Mladen Petric (Hamburg) left f...           1
# 1       Corner,  Borussia Dortmund. Conceded by Dennis...           2
# 2       Corner,  Borussia Dortmund. Conceded by Heiko ...           2
# 3                Foul by Sven Bender (Borussia Dortmund).           3
# ...

# %%
df.sort_values(by='side',ascending=False)
# Out:
#           id_odsp    id_event  sort_order  time  \
# 0       UFot0hit/   UFot0hit1           1     2
# 517938  EX9VAFWh/  EX9VAFWh58          58    64
# 517941  EX9VAFWh/  EX9VAFWh61          61    65
# 517942  EX9VAFWh/  EX9VAFWh62          62    66
# 517943  EX9VAFWh/  EX9VAFWh63          63    66
# ...           ...         ...         ...   ...
# 545008  Kzjg8ERk/  Kzjg8ERk30          30    38
# 545007  Kzjg8ERk/  Kzjg8ERk29          29    38
# 545005  Kzjg8ERk/  Kzjg8ERk27          27    37
# 545004  Kzjg8ERk/  Kzjg8ERk26          26    33
# 470504  0lrsF4ji/  0lrsF4ji61          61    56
#
#                                                      text  event_type  \
# 0       Attempt missed. Mladen Petric (Hamburg) left f...           1
# 517938      Foul by Gianni Bruno (Evian Thonon Gaillard).           3
# 517941  Corner,  Evian Thonon Gaillard. Conceded by Ri...           2
# 517942  Corner,  Evian Thonon Gaillard. Conceded by An...           2
# ...

# %%
df.sort_values(by=['time','opponent'],ascending=[True,False])
# Out:
#           id_odsp     id_event  sort_order  time  \
# 371243  UZlwdQ7b/    UZlwdQ7b2           2     0
# 388901  jVWrmK00/    jVWrmK001           1     0
# 475877  0WEr7Kjt/    0WEr7Kjt1           1     0
# 563859  lhahpTe4/    lhahpTe41           1     0
# 572716  4rl9B5f3/    4rl9B5f31           1     0
# ...           ...          ...         ...   ...
# 536761  IVwp48Un/  IVwp48Un102         102    99
# 559906  2HjCGcy7/   2HjCGcy798          98    99
# 559907  2HjCGcy7/   2HjCGcy799          99    99
# 924639  zmvq2Ub0/   zmvq2Ub082          82    99
# 559908  2HjCGcy7/  2HjCGcy7100         100   100
#
#                                                      text  event_type  \
# 371243               Foul by Raheem Sterling (Liverpool).           3
# 388901  Substitution, Cardiff City. Craig Bellamy repl...           7
# 475877             Foul by Samir Nasri (Manchester City).           3
# 563859  James Morrison (West Bromwich Albion) wins a f...           8
# ...

# %%
df.reset_index()
# Out:
#          index    id_odsp     id_event  sort_order  time  \
# 0            0  UFot0hit/    UFot0hit1           1     2
# 1            1  UFot0hit/    UFot0hit2           2     4
# 2            2  UFot0hit/    UFot0hit3           3     4
# 3            3  UFot0hit/    UFot0hit4           4     7
# 4            4  UFot0hit/    UFot0hit5           5     7
# ...        ...        ...          ...         ...   ...
# 941004  941004  z5L2OT5E/  z5L2OT5E123         123    92
# 941005  941005  z5L2OT5E/  z5L2OT5E124         124    93
# 941006  941006  z5L2OT5E/  z5L2OT5E125         125    93
# 941007  941007  z5L2OT5E/  z5L2OT5E126         126    94
# 941008  941008  z5L2OT5E/  z5L2OT5E127         127    94
#
#                                                      text  event_type  \
# 0       Attempt missed. Mladen Petric (Hamburg) left f...           1
# 1       Corner,  Borussia Dortmund. Conceded by Dennis...           2
# ...

# %%
df.replace(np.nan,0)
# Out:
#           id_odsp     id_event  sort_order  time  \
# 0       UFot0hit/    UFot0hit1           1     2
# 1       UFot0hit/    UFot0hit2           2     4
# 2       UFot0hit/    UFot0hit3           3     4
# 3       UFot0hit/    UFot0hit4           4     7
# 4       UFot0hit/    UFot0hit5           5     7
# ...           ...          ...         ...   ...
# 941004  z5L2OT5E/  z5L2OT5E123         123    92
# 941005  z5L2OT5E/  z5L2OT5E124         124    93
# 941006  z5L2OT5E/  z5L2OT5E125         125    93
# 941007  z5L2OT5E/  z5L2OT5E126         126    94
# 941008  z5L2OT5E/  z5L2OT5E127         127    94
#
#                                                      text  event_type  \
# 0       Attempt missed. Mladen Petric (Hamburg) left f...           1
# 1       Corner,  Borussia Dortmund. Conceded by Dennis...           2
# 2       Corner,  Borussia Dortmund. Conceded by Heiko ...           2
# 3                Foul by Sven Bender (Borussia Dortmund).           3
# ...

# %%
df.groupby('event_team')['time'].mean()
# Out:
# event_team
# AC Ajaccio           49.022047
# AC Milan             49.655377
# AJ Auxerre           49.922379
# AS Monaco            49.680000
# AS Nancy Lorraine    49.706550
#                        ...
# Villarreal           49.537949
# Watford              51.715664
# Werder Bremen        48.852231
# West Brom            50.954085
# West Ham             50.000500
# Name: time, Length: 142, dtype: float64

# %%
df.pivot_table(index='event_team',columns='opponent',values='is_goal',aggfunc='sum',fill_value=0)
# Out:
# opponent           AC Ajaccio  AC Milan  AJ Auxerre  AS Monaco  \
# event_team
# AC Ajaccio                  0         0           3          1
# AC Milan                    0         0           0          0
# AJ Auxerre                  5         0           0          0
# AS Monaco                   5         0           0          0
# AS Nancy Lorraine           3         0           3          0
# ...                       ...       ...         ...        ...
# Villarreal                  0         0           0          0
# Watford                     0         0           0          0
# Werder Bremen               0         0           0          0
# West Brom                   0         0           0          0
# West Ham                    0         0           0          0
#
# opponent           AS Nancy Lorraine  AS Roma  Alaves  Almeria  Angers  \
# event_team
# AC Ajaccio                         4        0       0        0       0
# ...
